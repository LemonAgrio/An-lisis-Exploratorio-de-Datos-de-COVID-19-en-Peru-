# %%
# Cargar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
print("Carpeta actual:", os.getcwd())
# Out:
# Carpeta actual: C:\Users\WILSON\covid-peru-analysis

# %%
import shutil
shutil.copy("C:/Users/WILSON/Downloads/covid_peru.csv", "../data/covid_peru.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import shutil
# ----> 2 shutil.copy("C:/Users/WILSON/Downloads/covid_peru.csv", "../data/covid_peru.csv")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1520.0_x64__qbz5n2kfra8p0\Lib\shutil.py:428, in copy(src, dst, follow_symlinks)
#     426 if os.path.isdir(dst):
#     427     dst = os.path.join(dst, os.path.basename(src))
# --> 428 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     429 copymode(src, dst, follow_symlinks=follow_symlinks)
#     430 return dst
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1520.0_x64__qbz5n2kfra8p0\Lib\shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
# ...

# %%
shutil.copy("C:/Users/WILSON/Downloads/COVID_PERU.csv.csv", "../data/covid_peru.csv")

# %%
df = pd.read_csv("../data/covid_peru", parse_dates=["Fecha"])
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("../data/covid_peru", parse_dates=["Fecha"])
#       2 df.info()
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
shutil.copy("C:/Users/WILSON/Downloads/COVID_PERU.csv.csv", "../data/covid_peru.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 shutil.copy("C:/Users/WILSON/Downloads/COVID_PERU.csv.csv", "../data/covid_peru.csv")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1520.0_x64__qbz5n2kfra8p0\Lib\shutil.py:428, in copy(src, dst, follow_symlinks)
#     426 if os.path.isdir(dst):
#     427     dst = os.path.join(dst, os.path.basename(src))
# --> 428 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     429 copymode(src, dst, follow_symlinks=follow_symlinks)
#     430 return dst
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1520.0_x64__qbz5n2kfra8p0\Lib\shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/covid_peru.csv")
print("Columnas:", df.columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/covid_peru.csv")
#       4 print("Columnas:", df.columns)
#       5 df.head()
#
# ...

# %%
import os
print(os.listdir("../data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import os
# ----> 2 print(os.listdir("../data"))
#
# FileNotFoundError: [WinError 3] El sistema no puede encontrar la ruta especificada: '../data'

# %%
import pandas as pd

df = pd.read_csv("../data/covid_peru.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/covid_peru.csv")
#       4 df.head()
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os

# Mostrar archivos dentro de la carpeta data
print("Archivos en carpeta '../data':", os.listdir("../data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 import os
#       3 # Mostrar archivos dentro de la carpeta data
# ----> 4 print("Archivos en carpeta '../data':", os.listdir("../data"))
#
# FileNotFoundError: [WinError 3] El sistema no puede encontrar la ruta especificada: '../data'

# %%
import pandas as pd

df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", parse_dates=['Fecha'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", parse_dates=['Fecha'])
#       4 df.head()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", parse_dates=['FECHA'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", parse_dates=['FECHA'])
#       4 df.head()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv")
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv")
#       4 print(df.columns)
#
# ...

# %%
df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", sep=';')
print(df.columns)
# Out:
# Index(['TIPO SEGURO', 'SEXO', 'EDAD', 'ESTADO CIVIL', 'PAIS DOMICILIO',
#        'DEPARTAMENTO DOMICILIO', 'FECHA', 'año', 'Unnamed: 8'],
#       dtype='object')
# C:\Users\WILSON\AppData\Local\Temp\ipykernel_5384\444288606.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", sep=';')

# %%
df = pd.read_csv(
    "C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv",
    sep=';',
    low_memory=False,
    parse_dates=['FECHA']
)
# Out:
# C:\Users\WILSON\AppData\Local\Temp\ipykernel_5384\4276448573.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv(

# %%
df = pd.read_csv(
    "C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv",
    sep=';',
    low_memory=False,
    parse_dates=['FECHA'],
    dayfirst=True
)

# %%
print(df['FECHA'].dtype)
# Out:
# object

# %%
# Ver dimensiones del dataset
print("Filas y columnas:", df.shape)

# Ver los primeros registros
df.head()

# Ver nombres y tipos de columnas
df.info()

# Estadísticas generales de columnas numéricas
df.describe()
# Out:
# Filas y columnas: (1048086, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048086 entries, 0 to 1048085
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   TIPO SEGURO             1047441 non-null  object
#  1   SEXO                    1045552 non-null  object
#  2   EDAD                    1037924 non-null  object
#  3   ESTADO CIVIL            1036092 non-null  object
#  4   PAIS DOMICILIO          1031141 non-null  object
#  5   DEPARTAMENTO DOMICILIO  1027657 non-null  object
#  6   FECHA                   1024005 non-null  object
#  7   año                     1023995 non-null  object
#  8   Unnamed: 8              16 non-null       object
# dtypes: object(9)
# memory usage: 72.0+ MB
#        TIPO SEGURO       SEXO     EDAD ESTADO CIVIL PAIS DOMICILIO  \
# count      1047441    1045552  1037924      1036092        1031141
# ...

# %%
df = df.drop(columns=['Unnamed: 8'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048086 entries, 0 to 1048085
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   TIPO SEGURO             1047441 non-null  object
#  1   SEXO                    1045552 non-null  object
#  2   EDAD                    1037924 non-null  object
#  3   ESTADO CIVIL            1036092 non-null  object
#  4   PAIS DOMICILIO          1031141 non-null  object
#  5   DEPARTAMENTO DOMICILIO  1027657 non-null  object
#  6   FECHA                   1024005 non-null  object
#  7   año                     1023995 non-null  object
# dtypes: object(8)
# memory usage: 64.0+ MB

# %%
df['FECHA'] = pd.to_datetime(df['FECHA'], dayfirst=True, errors='coerce')

# %%
df['FECHA'].dtype
df['FECHA'].head()
# Out:
# 0   2024-01-31
# 1   2024-02-01
# 2   2024-02-01
# 3   2018-12-25
# 4   2024-02-01
# Name: FECHA, dtype: datetime64[ns]

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# FECHA                     24139
# año                       24091
# DEPARTAMENTO DOMICILIO    20429
# PAIS DOMICILIO            16945
# ESTADO CIVIL              11994
# EDAD                      10162
# SEXO                       2534
# TIPO SEGURO                 645
# dtype: int64

# %%
df['EDAD'] = pd.to_numeric(df['EDAD'], errors='coerce')
df['EDAD'].describe()
# Out:
# count    1.023739e+06
# mean     6.690344e+01
# std      2.224290e+01
# min      0.000000e+00
# 25%      5.600000e+01
# 50%      7.200000e+01
# 75%      8.300000e+01
# max      2.021000e+03
# Name: EDAD, dtype: float64

# %%
df = df[(df['EDAD'] >= 0) & (df['EDAD'] <= 120)]

# %%
df['EDAD'].describe()
# Out:
# count    1.023738e+06
# mean     6.690153e+01
# std      2.215891e+01
# min      0.000000e+00
# 25%      5.600000e+01
# 50%      7.200000e+01
# 75%      8.300000e+01
# max      1.150000e+02
# Name: EDAD, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
df['EDAD'].hist(bins=50, color='skyblue', edgecolor='black')
plt.title('Distribución de Edad')
plt.xlabel('Edad')
plt.ylabel('Cantidad de casos')
plt.grid(True)
plt.show()

# %%
df['FECHA'] = pd.to_datetime(df['FECHA'], dayfirst=True, errors='coerce')
df['FECHA'].dt.year.value_counts().sort_index().plot(kind='bar', figsize=(8, 4), title='Casos por año', color='orange')
# Out:
# <Axes: title={'center': 'Casos por año'}, xlabel='FECHA'>

# %%
df['DEPARTAMENTO DOMICILIO'].value_counts().head(10).plot(kind='barh', title='Top 10 Departamentos con más casos', color='green')
# Out:
# <Axes: title={'center': 'Top 10 Departamentos con más casos'}, ylabel='DEPARTAMENTO DOMICILIO'>

# %%
# Análisis Exploratorio de Datos COVID-19 en Perú
# Autor: Roy Alarcón

import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos
ruta = "C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv"
df = pd.read_csv(ruta, sep=';', encoding='utf-8')

# Eliminar columna vacía
if 'Unnamed: 8' in df.columns:
    df.drop(columns=['Unnamed: 8'], inplace=True)

# Limpieza de columna FECHA
df['FECHA'] = pd.to_datetime(df['FECHA'], dayfirst=True, errors='coerce')

# Limpieza de columna EDAD
df['EDAD'] = pd.to_numeric(df['EDAD'], errors='coerce')
df = df[df['EDAD'].between(0, 115)]

# -------------------------------
# Visualización 1: Distribución de Edad
# -------------------------------
plt.figure(figsize=(10, 5))
df['EDAD'].hist(bins=50, color='skyblue', edgecolor='black')
plt.title('Distribución de Edad')
plt.xlabel('Edad')
plt.ylabel('Cantidad de casos')
plt.grid(True)
plt.tight_layout()
plt.show()

# -------------------------------
# Visualización 2: Casos por Año
# -------------------------------
df['AÑO'] = df['FECHA'].dt.year
plt.figure(figsize=(8, 4))
df['AÑO'].value_counts().sort_index().plot(kind='bar', color='orange')
plt.title('Casos por Año')
plt.xlabel('Año')
plt.ylabel('Cantidad de casos')
plt.tight_layout()
plt.show()

# -------------------------------
# Visualización 3: Casos por Departamento
# -------------------------------
plt.figure(figsize=(10, 6))
df['DEPARTAMENTO DOMICILIO'].value_counts().head(10).sort_values().plot(kind='barh', color='green')
plt.title('Top 10 Departamentos con más casos')
plt.xlabel('Cantidad de casos')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\WILSON\AppData\Local\Temp\ipykernel_5384\3875045390.py:9: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(ruta, sep=';', encoding='utf-8')

# %%
import seaborn as sns

# Agrupar edades por rangos
df['grupo_edad'] = pd.cut(df['EDAD'], bins=[0, 20, 40, 60, 80, 100, 120],
                          labels=['0-19', '20-39', '40-59', '60-79', '80-99', '100+'])

# Gráfico de barras
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='grupo_edad', hue='SEXO')
plt.title('Distribución de casos por grupo etario y sexo')
plt.xlabel('Grupo de edad')
plt.ylabel('Cantidad de casos')
plt.show()

# %%
casos_por_fecha = df['FECHA'].value_counts().sort_index()

plt.figure(figsize=(14, 6))
casos_por_fecha.plot()
plt.title('Evolución de casos en el tiempo')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de casos')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# PAIS DOMICILIO            162
# DEPARTAMENTO DOMICILIO    162
# grupo_edad                 74
# FECHA                       2
# AÑO                         2
# TIPO SEGURO                 0
# SEXO                        0
# ESTADO CIVIL                0
# EDAD                        0
# año                         0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
df.isnull().sum().sort_values(ascending=False).plot(kind='bar')
plt.title("Cantidad de valores nulos por columna")
plt.ylabel("Total de nulos")
plt.xticks(rotation=45)
plt.show()

# %%
df['SEXO'] = df['SEXO'].str.strip().str.upper()
df['SEXO'] = df['SEXO'].replace({'M': 'MASCULINO', 'F': 'FEMENINO'})  # si aplica

# %%
df['PAIS DOMICILIO'].value_counts().head(10)
# Out:
# PAIS DOMICILIO
# PERU                               1020726
# SIN REGISTRO                           858
# VENEZUELA                              539
# ESTADOS UNIDOS DE AMERICA              363
# CHILE                                  137
# ARGENTINA                              118
# ESPAÃ‘A                                115
# COLOMBIA                                86
# ECUADOR                                 80
# ITALIA                                  65
# Name: count, dtype: int64

# %%
df.to_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru_limpio.csv", index=False)

# %%
# Análisis de Datos COVID-19 en Perú
Este proyecto analiza una base de datos anónima de pacientes con diagnóstico confirmado de COVID-19 en Perú. Se revisan variables como edad, sexo, ubicación geográfica y tendencias temporales. El objetivo es obtener información exploratoria que ayude a entender el comportamiento del virus en distintas regiones del país.
# Out:
#   Cell In[38], line 2
#     Este proyecto analiza una base de datos anónima de pacientes con diagnóstico confirmado de COVID-19 en Perú. Se revisan variables como edad, sexo, ubicación geográfica y tendencias temporales. El objetivo es obtener información exploratoria que ayude a entender el comportamiento del virus en distintas regiones del país.
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos
df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", sep=";")

# Eliminar columna innecesaria
df = df.drop(columns=["Unnamed: 8"], errors="ignore")

# Convertir a fecha
df["FECHA"] = pd.to_datetime(df["FECHA"], dayfirst=True, errors="coerce")

# Corregir EDAD
df["EDAD"] = pd.to_numeric(df["EDAD"], errors="coerce")

# Limpiar texto de columnas categóricas
cat_cols = ["SEXO", "TIPO SEGURO", "ESTADO CIVIL", "PAIS DOMICILIO", "DEPARTAMENTO DOMICILIO"]
for col in cat_cols:
    df[col] = df[col].astype(str).str.strip().str.upper()
# Out:
# C:\Users\WILSON\AppData\Local\Temp\ipykernel_5384\3847728125.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", sep=";")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos
df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", sep=";")

# Eliminar columna innecesaria
df = df.drop(columns=["Unnamed: 8"], errors="ignore")

# Convertir a fecha
df["FECHA"] = pd.to_datetime(df["FECHA"], dayfirst=True, errors="coerce")

# Corregir EDAD
df["EDAD"] = pd.to_numeric(df["EDAD"], errors="coerce")

# Limpiar texto de columnas categóricas
cat_cols = ["SEXO", "TIPO SEGURO", "ESTADO CIVIL", "PAIS DOMICILIO", "DEPARTAMENTO DOMICILIO"]
for col in cat_cols:
    df[col] = df[col].astype(str).str.strip().str.upper()
# Out:
# C:\Users\WILSON\AppData\Local\Temp\ipykernel_5384\3847728125.py:6: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv", sep=";")

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df["EDAD"].dropna(), bins=30, kde=True)
plt.title("Distribución de la Edad")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %%
df["SEXO"].value_counts().plot(kind="bar", title="Casos por sexo")
plt.ylabel("Cantidad de casos")
plt.show()
# Out:
# C:\Users\WILSON\covid-peru-analysis\env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 141 (\x8d) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\WILSON\covid-peru-analysis\env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129 (\x81) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
top_departamentos = df["DEPARTAMENTO DOMICILIO"].value_counts().head(10)
top_departamentos.plot(kind="barh", title="Top 10 departamentos con más casos")
plt.xlabel("Cantidad de casos")
plt.gca().invert_yaxis()
plt.show()

# %%
df_fecha = df.dropna(subset=["FECHA"])
conteo_por_dia = df_fecha["FECHA"].value_counts().sort_index()

plt.figure(figsize=(15, 5))
conteo_por_dia.plot()
plt.title("Evolución diaria de casos reportados")
plt.xlabel("Fecha")
plt.ylabel("Número de casos")
plt.show()

# %%
df.to_csv("data/covid_peru_limpio.csv", index=False)

# %%
# Análisis de Datos COVID-19 en Perú

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración general de gráficos
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 5)

# 1. Carga de datos

# Leer CSV original
ruta = "C:/Users/WILSON/covid-peru-analysis/data/covid_peru.csv"
df = pd.read_csv(ruta, sep=';', encoding='utf-8')

# 2. Limpieza de datos

# Eliminar columnas innecesarias
if "Unnamed: 8" in df.columns:
    df = df.drop(columns=["Unnamed: 8"])

# Convertir fechas
df["FECHA"] = pd.to_datetime(df["FECHA"], dayfirst=True, errors='coerce')

# Convertir edad a numérico
df["EDAD"] = pd.to_numeric(df["EDAD"], errors='coerce')

# Normalizar texto en columnas categóricas
cat_cols = ["SEXO", "TIPO SEGURO", "ESTADO CIVIL", "PAIS DOMICILIO", "DEPARTAMENTO DOMICILIO"]
for col in cat_cols:
    df[col] = df[col].astype(str).str.strip().str.upper()

# 3. Análisis exploratorio

## 3.1 Distribución de edad
sns.histplot(df["EDAD"].dropna(), bins=30, kde=True)
plt.title("Distribución de la Edad")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

## 3.2 Casos por sexo
df["SEXO"].value_counts().plot(kind="bar", title="Casos por sexo")
plt.ylabel("Cantidad de casos")
plt.show()

## 3.3 Casos por departamento
top_deps = df["DEPARTAMENTO DOMICILIO"].value_counts().head(10)
top_deps.plot(kind="barh", title="Top 10 departamentos con más casos")
plt.xlabel("Cantidad de casos")
plt.gca().invert_yaxis()
plt.show()

## 3.4 Casos por fecha
conteo_por_fecha = df.dropna(subset=["FECHA"])["FECHA"].value_counts().sort_index()
conteo_por_fecha.plot()
plt.title("Evolución diaria de casos reportados")
plt.xlabel("Fecha")
plt.ylabel("Número de casos")
plt.show()

# 4. Exportar CSV limpio
df.to_csv("C:/Users/WILSON/covid-peru-analysis/data/covid_peru_limpio.csv", index=False)

# 5. Conclusiones
# - La mayoría de casos se concentran en Lima.
# - La edad promedio está en adultos mayores (media ≈ 67 años).
# - Predominan los casos del sexo masculino.
# - Se observa un patrón claro de crecimiento y descenso en ciertas fechas clave.
# Out:
# C:\Users\WILSON\AppData\Local\Temp\ipykernel_5384\2915194643.py:15: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(ruta, sep=';', encoding='utf-8')
# C:\Users\WILSON\covid-peru-analysis\env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 141 (\x8d) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\WILSON\covid-peru-analysis\env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129 (\x81) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
