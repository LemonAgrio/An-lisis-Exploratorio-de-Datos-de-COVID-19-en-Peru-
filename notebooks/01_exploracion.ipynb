# %%
import panda as pd 
import matplotlib.pylot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import panda as pd
#       2 import matplotlib.pylot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
print(df.head())
print(df.describe())plt.figure(figsize=(10,5))
plt.plot(df['Fecha'], df['Casos'], marker='o', label='Casos', color='blue')
plt.plot(df['Fecha'], df['Muertes'], marker='x', label='Muertes', color='red')
plt.title("Casos y Muertes por COVID-19 en Perú")
plt.xlabel("Fecha")
plt.ylabel("Cantidad")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#   Cell In[3], line 3
#     print(df.describe())plt.figure(figsize=(10,5))
#                         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo visual
sns.set(style="darkgrid")

# Cargar los datos
df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])

# Ver primeras filas
print(df.head())

# Descripción estadística
print(df.describe())

# Gráfico de Casos y Muertes
plt.figure(figsize=(10,5))
plt.plot(df['Fecha'], df['Casos'], marker='o', label='Casos', color='blue')
plt.plot(df['Fecha'], df['Muertes'], marker='x', label='Muertes', color='red')
plt.title("Casos y Muertes por COVID-19 en Perú")
plt.xlabel("Fecha")
plt.ylabel("Cantidad")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 sns.set(style="darkgrid")
#       8 # Cargar los datos
# ----> 9 df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
#      11 # Ver primeras filas
#      12 print(df.head())
#
# ...

# %%
df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv('C:/Users/WILSON/Downloads/covid_peru.csv', parse_dates=['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv('C:/Users/WILSON/Downloads/covid_peru.csv', parse_dates=['Fecha'])
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo visual
sns.set(style="darkgrid")

# Cargar los datos
df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])

# Ver primeras filas
print(df.head())

# Descripción estadística
print(df.describe())

# Gráfico de Casos y Muertes
plt.figure(figsize=(10,5))
plt.plot(df['Fecha'], df['Casos'], marker='o', label='Casos', color='blue')
plt.plot(df['Fecha'], df['Muertes'], marker='x', label='Muertes', color='red')
plt.title("Casos y Muertes por COVID-19 en Perú")
plt.xlabel("Fecha")
plt.ylabel("Cantidad")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 9
#       6 sns.set(style="darkgrid")
#       8 # Cargar los datos
# ----> 9 df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
#      11 # Ver primeras filas
#      12 print(df.head())
#
# ...

# %%
df = pd.read_excel('C:/Users/WILSON/Downloads/covid_peru.xlsx', parse_dates=['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_excel('C:/Users/WILSON/Downloads/covid_peru.xlsx', parse_dates=['Fecha'])
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print("Estoy en:", os.getcwd())
print("Archivos en carpeta 'data':", os.listdir("../data"))
# Out:
# Estoy en: C:\Users\WILSON\covid-peru-analysis\notebooks
# Archivos en carpeta 'data': ['covid_peru.csv.csv']

# %%
df = pd.read_csv('../data/covid_peru.csv.csv', parse_dates=['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv('../data/covid_peru.csv.csv', parse_dates=['Fecha'])
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print("Estás en:", os.getcwd())
print("Archivos en '../data':", os.listdir("../data"))
# Out:
# Estás en: C:\Users\WILSON\covid-peru-analysis\notebooks
# Archivos en '../data': ['covid_peru.csv.csv.csv']

# %%
df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv('../data/covid_peru.csv', parse_dates=['Fecha'])
#
# File ~\covid-peru-analysis\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/covid_peru.csv.csv.csv')  # o el nombre correcto del archivo real
print("Columnas del archivo:", df.columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('../data/covid_peru.csv.csv.csv')  # o el nombre correcto del archivo real
#       4 print("Columnas del archivo:", df.columns)
#       5 df.head()
#
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/covid_peru')  # o el nombre correcto del archivo real
print("Columnas del archivo:", df.columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('../data/covid_peru')  # o el nombre correcto del archivo real
#       4 print("Columnas del archivo:", df.columns)
#       5 df.head()
#
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/covid_peru.csv')  # o el nombre correcto del archivo real
print("Columnas del archivo:", df.columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('../data/covid_peru.csv')  # o el nombre correcto del archivo real
#       4 print("Columnas del archivo:", df.columns)
#       5 df.head()
#
# ...

# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
Using matplotlib backend: module://matplotlib_inline.backend_inline
# Out:
#   Cell In[2], line 1
#     Using matplotlib backend: module://matplotlib_inline.backend_inline
#           ^
# SyntaxError: invalid syntax
